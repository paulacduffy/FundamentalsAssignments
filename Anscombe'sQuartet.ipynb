# %% [markdown]
# # Anscombe's Quartet Analysis

# %% [markdown]
# ### Introduction
# Anscombe's Quartet comprises four datasets that have nearly identical descriptive statistics, yet appear very different when graphed.
# It shows that four datasets with identical statistical properties can actually be very different, emphasising the importance of using graphs in statistical analysis.
# It was published by Francis J Anscombe in 1973 in a paper entitled Graphs in Statistical Analysis. The abstract for the paper simply stated "Graphs are essential to good statistical analysis".
# It presents a table of numbers containing four distinct datasets, each with statistical properties that are essentially identical:
# Mean of x values is 9.0
# Mean of y values is 7.5
# All have nearly identical variances, correlations & regression lines, yet when graphed the datasets look completely distinctive from each other.

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
anscombe = sns.load_dataset("anscombe")
anscombe
#importing relevant libraries & the Anscombe dataset
#displaying dataset below:
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
import seaborn as sns
df = sns.load_dataset("anscombe")
df.groupby("dataset").describe()
# Out:
#             x                                               y            \
#         count mean       std  min  25%  50%   75%   max count      mean
# dataset
# I        11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# II       11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# III      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# IV       11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#               std   min    25%   50%   75%    max
# dataset
# I        2.031568  4.26  6.315  7.58  8.57  10.84
# II       2.031657  3.10  6.695  8.14  8.95   9.26
# III      2.030424  5.39  6.250  7.11  7.98  12.74
# IV       2.030579  5.25  6.170  7.04  8.19  12.50

# %% [markdown]
# We can see from the description of the datasets above that they are very similar.

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline
sns.set(style="ticks")
df = sns.load_dataset ("anscombe")
sns.lmplot(x="x", y="y", col="dataset", hue="dataset", data=df,
           col_wrap=2, ci=None, palette="muted", 
           scatter_kws={"s": 50, "alpha": 1})

# %% [markdown]
# We can see all datasets have the same regression line also, however looking at the scatterplots behind the regression lines, we see completely different plots.
# Dataset I is roughly linear, dataset II is a curve, dataset III has an outlier that is pulling the regression line away from the rest of the data, and dataset IV doesn't fit a linear model, the value of x stays constant apart from one outlier, which gives the same correlation as the other datasets, but a liner relationship doesn't exist.
# Anscombe's quartet is used to illustrate the importance of visualisation in data analysis.

# %% [markdown]
# ### References
# https://seaborn.pydata.org/examples/anscombes_quartet.html
# https://en.wikipedia.org/wiki/Anscombe's_quartet
